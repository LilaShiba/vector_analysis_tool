# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from vectors import Vector

# %%
df = pd.read_csv('vectors_helper/temps.csv', parse_dates=['date'])

# %%
temps = Vector(label='temps', data_points=df['min'])
plt.plot(temps.v)

# %%
temps.plot_basic_stats()

# %%
temps.log_binning()
# Out:
# (0.01098901098901099, 7.967032967032967)

# %%
temps.linear_scale()

# %%
ra =temps.rolling_average(window_size=50)

# %%
plt.scatter(x=ra, y=[x for x in range(len(ra))])

# %%
world_temps = 'global_temp_data/GlobalTemperatures.csv'
df = pd.read_csv(world_temps, parse_dates=['dt'])
wt = Vector(label='world_temps', data_points= df['LandMaxTemperature'], dates=df['dt'])

# %%
wt.plot_basic_stats()

# %%
plt.plot(wt.v)

# %%
wt.pearson_correlation()
# Out:
# 0.08569292355316036

# %%
wt.standardize_data()
plt.plot(wt.v)

# %%
wt.linear_scale()

# %%
wt.log_binning()
# Out:
# (0.0005512679162072767, 0.0016538037486218302)

# %%
wt.normalize_data()
wt.linear_scale()

# %%
wt.log_binning()
# Out:
# (0.0005512679162072767, 0.0016538037486218302)

# %%
wt.pearson_correlation()
# Out:
# 0.08569292355316036

# %%
plt.plot(np.cumsum(wt.v))

# %%
wt.simple_linear_regression()
# Out:
# (2.1094644722838225e-05, 13.711454093722287)

# %%
wt.v
# Out:
# array([0.15188067, 0.26394293, 0.2883917 , ..., 0.68417639, 0.45343709,
#        0.31290532])

# %%
wt.y
y = wt.normalize_data()

# %%
print(y)
# Out:
# [0.15188067 0.26394293 0.2883917  ... 0.68417639 0.45343709 0.31290532]

# %%
decade = [x for idx, x in enumerate(wt.y) if idx % 10 == 0]

# %%
plt.plot(decade)

# %%
df.head()
# Out:
#           dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0 1750-01-01                   3.034                              3.574
# 1 1750-02-01                   3.083                              3.702
# 2 1750-03-01                   5.626                              3.076
# 3 1750-04-01                   8.490                              2.451
# 4 1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
df['date'] = pd.to_datetime(df['dt'])

# %%
df.head()
# Out:
#           dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0 1750-01-01                   3.034                              3.574
# 1 1750-02-01                   3.083                              3.702
# 2 1750-03-01                   5.626                              3.076
# 3 1750-04-01                   8.490                              2.451
# 4 1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
df_jan = df[df['date'].dt.month == 2]
jan = Vector(label='jan', data_points=df_jan['LandAverageTemperature'])
plt.plot(jan.y)

# %%
plt.plot(df_jan['date'], df_jan['LandAverageTemperature'])
